# %%
import os
from PIL import Image

def resize_images_in_folder(input_folder, output_folder, new_width, new_height):
    """
    Resizes all images in the input folder and saves them to the output folder.

    Args:
        input_folder: Path to the folder containing images to resize.
        output_folder: Path to the folder where resized images will be saved.
        new_width: Desired width of the resized images in pixels.
        new_height: Desired height of the resized images in pixels.
    """
    if not os.path.exists(input_folder):
        print(f"Error: Input folder '{input_folder}' does not exist.")
        return

    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    for filename in os.listdir(input_folder):
        input_path = os.path.join(input_folder, filename)

        if not os.path.isfile(input_path):
            continue  # Skip non-file entries (e.g., directories)

        try:
            with Image.open(input_path) as image:
                resized_image = image.resize((new_width, new_height))
                output_path = os.path.join(output_folder, filename)
                resized_image.save(output_path)
                print(f"Resized '{filename}' and saved to '{output_path}'")
        except Exception as e:
            print(f"Error processing file '{filename}': {e}")

# Command-line input for folders
input_folder = input("Enter the path to the input folder: ").strip()
if not input_folder or not os.path.exists(input_folder):
    print("Invalid input folder. Exiting.")
    exit()

output_folder = input("Enter the path to the output folder: ").strip()
if not output_folder:
    print("Invalid output folder. Exiting.")
    exit()

# Resize all images in the folder to the specified dimensions
import os
from PIL import Image

def resize_images_in_folder(input_folder, output_folder, new_width, new_height):
    """
    Resizes all images in the input folder and saves them to the output folder.

    Args:
        input_folder: Path to the folder containing images to resize.
        output_folder: Path to the folder where resized images will be saved.
        new_width: Desired width of the resized images in pixels.
        new_height: Desired height of the resized images in pixels.
    """
    if not os.path.exists(input_folder):
        print(f"Error: Input folder '{input_folder}' does not exist.")
        return

    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    for filename in os.listdir(input_folder):
        input_path = os.path.join(input_folder, filename)

        if not os.path.isfile(input_path):
            continue  # Skip non-file entries (e.g., directories)

        try:
            with Image.open(input_path) as image:
                resized_image = image.resize((new_width, new_height))
                output_path = os.path.join(output_folder, filename)
                resized_image.save(output_path)
                print(f"Resized '{filename}' and saved to '{output_path}'")
        except Exception as e:
            print(f"Error processing file '{filename}': {e}")

# Command-line input for folders
input_folder = input("/content/drive/MyDrive/zebra serengeti").strip()
if not input_folder or not os.path.exists(input_folder):
    print("Invalid input folder. Exiting.")
    exit()

output_folder = input("/content/drive/MyDrive/zebra serengetir").strip()
if not output_folder:
    print("Invalid output folder. Exiting.")
    exit()

# Resize all images in the folder to the specified dimensions
new_width = 640
new_height = 640
resize_images_in_folder(input_folder, output_folder, new_width, new_height)
# Out:
# Enter the path to the input folder: /content/drive/MyDrive/serengeti ele
# Enter the path to the output folder: /content/drive/MyDrive/serengeti eler
# /content/drive/MyDrive/zebra serengeti/content/drive/MyDrive/serengeti ele
# /content/drive/MyDrive/zebra serengetir/content/drive/MyDrive/serengeti eler
# Resized 'S1_B05_R1_PICT0056.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_B05_R1_PICT0056.JPG'
# Resized 'S1_B06_R1_PICT0007.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_B06_R1_PICT0007.JPG'
# Resized 'S1_B05_R3_PICT0039.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_B05_R3_PICT0039.JPG'
# Resized 'S1_B05_R3_PICT0038.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_B05_R3_PICT0038.JPG'
# Resized 'S1_B05_R3_PICT0056.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_B05_R3_PICT0056.JPG'
# Resized 'S1_B05_R1_PICT0057.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_B05_R1_PICT0057.JPG'
# Resized 'S1_B06_R1_PICT0038.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_B06_R1_PICT0038.JPG'
# Resized 'S1_B05_R3_PICT0058.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_B05_R3_PICT0058.JPG'
# Resized 'S1_B05_R3_PICT0040.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_B05_R3_PICT0040.JPG'
# Resized 'S1_B05_R3_PICT0057.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_B05_R3_PICT0057.JPG'
# Resized 'S1_B06_R1_PICT0008.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_B06_R1_PICT0008.JPG'
# Resized 'S1_B06_R1_PICT0037.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_B06_R1_PICT0037.JPG'
# Resized 'S1_B06_R2_PICT0006.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_B06_R2_PICT0006.JPG'
# Resized 'S1_B06_R2_PICT0028.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_B06_R2_PICT0028.JPG'
# Resized 'S1_B06_R1_PICT0039.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_B06_R1_PICT0039.JPG'
# Resized 'S1_B07_R1_PICT0435.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_B07_R1_PICT0435.JPG'
# Resized 'S1_B06_R1_PICT0049.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_B06_R1_PICT0049.JPG'
# Resized 'S1_B06_R1_PICT0064.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_B06_R1_PICT0064.JPG'
# Resized 'S1_B06_R1_PICT0065.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_B06_R1_PICT0065.JPG'
# Resized 'S1_B06_R1_PICT0056.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_B06_R1_PICT0056.JPG'
# Resized 'S1_B06_R2_PICT0029.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_B06_R2_PICT0029.JPG'
# Resized 'S1_B06_R1_PICT0048.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_B06_R1_PICT0048.JPG'
# Resized 'S1_B06_R1_PICT0067.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_B06_R1_PICT0067.JPG'
# Resized 'S1_B06_R1_PICT0066.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_B06_R1_PICT0066.JPG'
# Resized 'S1_B06_R2_PICT0027.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_B06_R2_PICT0027.JPG'
# Resized 'S1_C05_R3_PICT0170.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_C05_R3_PICT0170.JPG'
# Resized 'S1_C06_R1_PICT0056.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_C06_R1_PICT0056.JPG'
# Resized 'S1_C05_R3_PICT0171.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_C05_R3_PICT0171.JPG'
# Resized 'S1_C05_R3_PICT0172.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_C05_R3_PICT0172.JPG'
# Resized 'S1_B07_R1_PICT0437.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_B07_R1_PICT0437.JPG'
# Resized 'S1_C06_R3_PICT2297.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_C06_R3_PICT2297.JPG'
# Resized 'S1_C05_R3_PICT0899.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_C05_R3_PICT0899.JPG'
# Resized 'S1_C05_R3_PICT0901.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_C05_R3_PICT0901.JPG'
# Resized 'S1_C05_R3_PICT0898.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_C05_R3_PICT0898.JPG'
# Resized 'S1_C05_R3_PICT0897.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_C05_R3_PICT0897.JPG'
# Resized 'S1_B07_R1_PICT0436.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_B07_R1_PICT0436.JPG'
# Resized 'S1_C05_R3_PICT0900.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_C05_R3_PICT0900.JPG'
# Resized 'S1_C06_R4_PICT0182.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_C06_R4_PICT0182.JPG'
# Resized 'S1_C06_R4_PICT0454.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_C06_R4_PICT0454.JPG'
# Resized 'S1_C06_R4_PICT0185.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_C06_R4_PICT0185.JPG'
# Resized 'S1_C06_R4_PICT0183.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_C06_R4_PICT0183.JPG'
# Resized 'S1_C06_R4_PICT0452.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_C06_R4_PICT0452.JPG'
# Resized 'S1_C06_R4_PICT0465.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_C06_R4_PICT0465.JPG'
# Resized 'S1_C06_R3_PICT2298.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_C06_R3_PICT2298.JPG'
# Resized 'S1_C06_R4_PICT0184.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_C06_R4_PICT0184.JPG'
# Resized 'S1_C06_R4_PICT0453.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_C06_R4_PICT0453.JPG'
# Resized 'S1_C06_R4_PICT0464.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_C06_R4_PICT0464.JPG'
# Resized 'S1_C06_R4_PICT0186.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_C06_R4_PICT0186.JPG'
# Resized 'S1_C06_R3_PICT2299.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_C06_R3_PICT2299.JPG'
# Resized 'S1_C06_R4_PICT0187.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_C06_R4_PICT0187.JPG'
# Resized 'S1_D03_R2_PICT0020.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D03_R2_PICT0020.JPG'
# Resized 'S1_D03_R1_PICT0016.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D03_R1_PICT0016.JPG'
# Resized 'S1_C06_R4_PICT0493.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_C06_R4_PICT0493.JPG'
# Resized 'S1_D02_R1_PICT1841.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D02_R1_PICT1841.JPG'
# Resized 'S1_D02_R1_PICT1842.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D02_R1_PICT1842.JPG'
# Resized 'S1_D02_R1_PICT1249.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D02_R1_PICT1249.JPG'
# Resized 'S1_D02_R1_PICT1248.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D02_R1_PICT1248.JPG'
# Resized 'S1_D02_R1_PICT1843.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D02_R1_PICT1843.JPG'
# Resized 'S1_C06_R4_PICT0492.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_C06_R4_PICT0492.JPG'
# Resized 'S1_C06_R4_PICT0491.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_C06_R4_PICT0491.JPG'
# Resized 'S1_D02_R1_PICT1247.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D02_R1_PICT1247.JPG'
# Resized 'S1_C06_R4_PICT0466.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_C06_R4_PICT0466.JPG'
# Resized 'S1_D02_R1_PICT1255.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D02_R1_PICT1255.JPG'
# Resized 'S1_D03_R1_PICT0046.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D03_R1_PICT0046.JPG'
# Resized 'S1_D03_R5_PICT0407.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D03_R5_PICT0407.JPG'
# Resized 'S1_D03_R2_PICT0022.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D03_R2_PICT0022.JPG'
# Resized 'S1_D03_R7_PICT0090.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D03_R7_PICT0090.JPG'
# Resized 'S1_D03_R2_PICT0021.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D03_R2_PICT0021.JPG'
# Resized 'S1_D03_R7_PICT0097.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D03_R7_PICT0097.JPG'
# Resized 'S1_D03_R7_PICT0095.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D03_R7_PICT0095.JPG'
# Resized 'S1_D03_R7_PICT0094.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D03_R7_PICT0094.JPG'
# Resized 'S1_D03_R7_PICT0096.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D03_R7_PICT0096.JPG'
# Resized 'S1_D03_R7_PICT0088.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D03_R7_PICT0088.JPG'
# Resized 'S1_D03_R7_PICT0092.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D03_R7_PICT0092.JPG'
# Resized 'S1_D03_R5_PICT0408.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D03_R5_PICT0408.JPG'
# Resized 'S1_D03_R7_PICT0089.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D03_R7_PICT0089.JPG'
# Resized 'S1_D03_R7_PICT0093.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D03_R7_PICT0093.JPG'
# Resized 'S1_D03_R5_PICT0406.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D03_R5_PICT0406.JPG'
# Resized 'S1_D03_R7_PICT0091.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D03_R7_PICT0091.JPG'
# Resized 'S1_D03_R7_PICT0101.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D03_R7_PICT0101.JPG'
# Resized 'S1_D03_R7_PICT0098.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D03_R7_PICT0098.JPG'
# Resized 'S1_D03_R7_PICT0103.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D03_R7_PICT0103.JPG'
# Resized 'S1_D03_R7_PICT0099.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D03_R7_PICT0099.JPG'
# Resized 'S1_D03_R7_PICT0105.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D03_R7_PICT0105.JPG'
# Resized 'S1_D04_R4_PICT0123.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D04_R4_PICT0123.JPG'
# Resized 'S1_D03_R7_PICT0107.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D03_R7_PICT0107.JPG'
# Resized 'S1_D03_R7_PICT0102.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D03_R7_PICT0102.JPG'
# Resized 'S1_D03_R7_PICT0104.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D03_R7_PICT0104.JPG'
# Resized 'S1_D03_R7_PICT0108.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D03_R7_PICT0108.JPG'
# Resized 'S1_D03_R7_PICT0100.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D03_R7_PICT0100.JPG'
# Resized 'S1_D03_R7_PICT0106.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D03_R7_PICT0106.JPG'
# Resized 'S1_D04_R1_PICT0118.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D04_R1_PICT0118.JPG'
# Resized 'S1_D04_R4_PICT0173.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D04_R4_PICT0173.JPG'
# Resized 'S1_D04_R5_PICT0042.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D04_R5_PICT0042.JPG'
# Resized 'S1_D04_R4_PICT0127.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D04_R4_PICT0127.JPG'
# Resized 'S1_D04_R5_PICT0043.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D04_R5_PICT0043.JPG'
# Resized 'S1_D04_R4_PICT0126.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D04_R4_PICT0126.JPG'
# Resized 'S1_D04_R4_PICT0124.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D04_R4_PICT0124.JPG'
# Resized 'S1_D04_R4_PICT0171.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D04_R4_PICT0171.JPG'
# Resized 'S1_D04_R4_PICT0128.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D04_R4_PICT0128.JPG'
# Resized 'S1_D04_R5_PICT0041.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D04_R5_PICT0041.JPG'
# Resized 'S1_D04_R4_PICT0172.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D04_R4_PICT0172.JPG'
# Resized 'S1_D04_R5_PICT0127.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D04_R5_PICT0127.JPG'
# Resized 'S1_D04_R5_PICT0126.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D04_R5_PICT0126.JPG'
# Resized 'S1_D04_R5_PICT0158.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D04_R5_PICT0158.JPG'
# Resized 'S1_D04_R5_PICT0155.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D04_R5_PICT0155.JPG'
# Resized 'S1_D04_R6_PICT0020.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D04_R6_PICT0020.JPG'
# Resized 'S1_D04_R5_PICT0160.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D04_R5_PICT0160.JPG'
# Resized 'S1_D04_R6_PICT0019.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D04_R6_PICT0019.JPG'
# Resized 'S1_D04_R6_PICT0018.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D04_R6_PICT0018.JPG'
# Resized 'S1_D04_R6_PICT0017.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D04_R6_PICT0017.JPG'
# Resized 'S1_D04_R5_PICT0157.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D04_R5_PICT0157.JPG'
# Resized 'S1_D04_R6_PICT0021.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D04_R6_PICT0021.JPG'
# Resized 'S1_D04_R5_PICT0156.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D04_R5_PICT0156.JPG'
# Resized 'S1_D04_R5_PICT0159.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D04_R5_PICT0159.JPG'
# Resized 'S1_D04_R5_PICT0125.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D04_R5_PICT0125.JPG'
# Resized 'S1_D04_R6_PICT0022.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D04_R6_PICT0022.JPG'
# Resized 'S1_D06_R1_PICT1875.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D06_R1_PICT1875.JPG'
# Resized 'S1_D06_R1_PICT2722.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D06_R1_PICT2722.JPG'
# Resized 'S1_D04_R6_PICT0462.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D04_R6_PICT0462.JPG'
# Resized 'S1_D04_R6_PICT0461.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D04_R6_PICT0461.JPG'
# Resized 'S1_D07_R1_PICT0030.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D07_R1_PICT0030.JPG'
# Resized 'S1_D06_R2_PICT0423.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D06_R2_PICT0423.JPG'
# Resized 'S1_D06_R2_PICT0422.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D06_R2_PICT0422.JPG'
# Resized 'S1_D06_R2_PICT0424.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D06_R2_PICT0424.JPG'
# Resized 'S1_D06_R1_PICT1874.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D06_R1_PICT1874.JPG'
# Resized 'S1_D07_R1_PICT0033.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D07_R1_PICT0033.JPG'
# Resized 'S1_D07_R1_PICT0003.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D07_R1_PICT0003.JPG'
# Resized 'S1_D07_R1_PICT0007.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D07_R1_PICT0007.JPG'
# Resized 'S1_D04_R6_PICT0463.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D04_R6_PICT0463.JPG'
# Resized 'S1_D07_R1_PICT0005.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D07_R1_PICT0005.JPG'
# Resized 'S1_D07_R2_PICT0023.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D07_R2_PICT0023.JPG'
# Resized 'S1_D07_R1_PICT0042.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D07_R1_PICT0042.JPG'
# Resized 'S1_D07_R2_PICT0020.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D07_R2_PICT0020.JPG'
# Resized 'S1_D07_R1_PICT0041.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D07_R1_PICT0041.JPG'
# Resized 'S1_D07_R2_PICT0025.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D07_R2_PICT0025.JPG'
# Resized 'S1_D07_R2_PICT0021.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D07_R2_PICT0021.JPG'
# Resized 'S1_D07_R2_PICT0030.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D07_R2_PICT0030.JPG'
# Resized 'S1_D07_R2_PICT0027.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D07_R2_PICT0027.JPG'
# Resized 'S1_D07_R2_PICT0028.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D07_R2_PICT0028.JPG'
# Resized 'S1_D07_R1_PICT0034.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D07_R1_PICT0034.JPG'
# Resized 'S1_D07_R2_PICT0026.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D07_R2_PICT0026.JPG'
# Resized 'S1_D07_R2_PICT0024.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D07_R2_PICT0024.JPG'
# Resized 'S1_D07_R2_PICT0022.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D07_R2_PICT0022.JPG'
# Resized 'S1_D07_R2_PICT0029.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D07_R2_PICT0029.JPG'
# Resized 'S1_D07_R3_PICT0084.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D07_R3_PICT0084.JPG'
# Resized 'S1_D07_R3_PICT0085.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D07_R3_PICT0085.JPG'
# Resized 'S1_D07_R3_PICT0071.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D07_R3_PICT0071.JPG'
# Resized 'S1_D07_R3_PICT0072.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D07_R3_PICT0072.JPG'
# Resized 'S1_D07_R3_PICT0252.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D07_R3_PICT0252.JPG'
# Resized 'S1_D07_R3_PICT0251.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D07_R3_PICT0251.JPG'
# Resized 'S1_D07_R2_PICT0036.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D07_R2_PICT0036.JPG'
# Resized 'S1_D07_R3_PICT0086.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D07_R3_PICT0086.JPG'
# Resized 'S1_D07_R2_PICT0037.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D07_R2_PICT0037.JPG'
# Resized 'S1_D07_R2_PICT0031.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D07_R2_PICT0031.JPG'
# Resized 'S1_D07_R3_PICT0088.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D07_R3_PICT0088.JPG'
# Resized 'S1_D07_R3_PICT0073.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D07_R3_PICT0073.JPG'
# Resized 'S1_D07_R2_PICT0035.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D07_R2_PICT0035.JPG'
# Resized 'S1_D07_R3_PICT0083.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D07_R3_PICT0083.JPG'
# Resized 'S1_D07_R3_PICT0087.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D07_R3_PICT0087.JPG'
# Resized 'S1_D11_R1_PICT0027.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D11_R1_PICT0027.JPG'
# Resized 'S1_D07_R3_PICT0266.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D07_R3_PICT0266.JPG'
# Resized 'S1_D07_R3_PICT0260.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D07_R3_PICT0260.JPG'
# Resized 'S1_D07_R3_PICT0256.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D07_R3_PICT0256.JPG'
# Resized 'S1_D07_R3_PICT0257.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D07_R3_PICT0257.JPG'
# Resized 'S1_D07_R3_PICT0254.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D07_R3_PICT0254.JPG'
# Resized 'S1_D07_R3_PICT0262.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D07_R3_PICT0262.JPG'
# Resized 'S1_D07_R3_PICT0268.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D07_R3_PICT0268.JPG'
# Resized 'S1_D07_R3_PICT0255.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D07_R3_PICT0255.JPG'
# Resized 'S1_D11_R1_PICT0026.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D11_R1_PICT0026.JPG'
# Resized 'S1_D07_R3_PICT0253.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D07_R3_PICT0253.JPG'
# Resized 'S1_D07_R3_PICT0267.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D07_R3_PICT0267.JPG'
# Resized 'S1_D07_R3_PICT0259.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D07_R3_PICT0259.JPG'
# Resized 'S1_D07_R3_PICT0258.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D07_R3_PICT0258.JPG'
# Resized 'S1_D07_R3_PICT0261.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D07_R3_PICT0261.JPG'
# Resized 'S1_D11_R1_PICT0045.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D11_R1_PICT0045.JPG'
# Resized 'S1_D12_R1_PICT0309.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D12_R1_PICT0309.JPG'
# Resized 'S1_D11_R1_PICT0046.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D11_R1_PICT0046.JPG'
# Resized 'S1_E02_R3_PICT0120.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_E02_R3_PICT0120.JPG'
# Resized 'S1_D11_R1_PICT0028.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D11_R1_PICT0028.JPG'
# Resized 'S1_D11_R1_PICT0044.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D11_R1_PICT0044.JPG'
# Resized 'S1_E02_R3_PICT0119.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_E02_R3_PICT0119.JPG'
# Resized 'S1_D12_R1_PICT0308.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D12_R1_PICT0308.JPG'
# Resized 'S1_D12_R1_PICT0305.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D12_R1_PICT0305.JPG'
# Resized 'S1_D12_R1_PICT0306.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D12_R1_PICT0306.JPG'
# Resized 'S1_D12_R1_PICT0307.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D12_R1_PICT0307.JPG'
# Resized 'S1_D12_R1_PICT0310.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_D12_R1_PICT0310.JPG'
# Resized 'S1_E02_R5_PICT0029.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_E02_R5_PICT0029.JPG'
# Resized 'S1_E02_R5_PICT0030.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_E02_R5_PICT0030.JPG'
# Resized 'S1_E02_R3_PICT0147.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_E02_R3_PICT0147.JPG'
# Resized 'S1_E02_R5_PICT0021.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_E02_R5_PICT0021.JPG'
# Resized 'S1_E02_R3_PICT0122.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_E02_R3_PICT0122.JPG'
# Resized 'S1_E02_R3_PICT0148.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_E02_R3_PICT0148.JPG'
# Resized 'S1_E02_R3_PICT0124.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_E02_R3_PICT0124.JPG'
# Resized 'S1_E02_R3_PICT0151.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_E02_R3_PICT0151.JPG'
# Resized 'S1_E02_R5_PICT0028.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_E02_R5_PICT0028.JPG'
# Resized 'S1_E02_R3_PICT0149.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_E02_R3_PICT0149.JPG'
# Resized 'S1_E02_R3_PICT0121.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_E02_R3_PICT0121.JPG'
# Resized 'S1_E02_R3_PICT0150.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_E02_R3_PICT0150.JPG'
# Resized 'S1_E02_R3_PICT0123.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_E02_R3_PICT0123.JPG'
# Resized 'S1_E02_R3_PICT0146.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_E02_R3_PICT0146.JPG'
# Resized 'S1_E02_R5_PICT0032.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_E02_R5_PICT0032.JPG'
# Resized 'S1_E02_R5_PICT0035.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_E02_R5_PICT0035.JPG'
# Resized 'S1_E02_R5_PICT0042.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_E02_R5_PICT0042.JPG'
# Resized 'S1_E02_R5_PICT0044.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_E02_R5_PICT0044.JPG'
# Resized 'S1_E02_R5_PICT0034.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_E02_R5_PICT0034.JPG'
# Resized 'S1_E02_R5_PICT0040.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_E02_R5_PICT0040.JPG'
# Resized 'S1_E02_R5_PICT0041.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_E02_R5_PICT0041.JPG'
# Resized 'S1_E02_R5_PICT0038.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_E02_R5_PICT0038.JPG'
# Resized 'S1_E02_R5_PICT0033.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_E02_R5_PICT0033.JPG'
# Resized 'S1_E02_R5_PICT0031.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_E02_R5_PICT0031.JPG'
# Resized 'S1_E02_R5_PICT0037.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_E02_R5_PICT0037.JPG'
# Resized 'S1_E02_R5_PICT0036.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_E02_R5_PICT0036.JPG'
# Resized 'S1_E02_R5_PICT0039.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_E02_R5_PICT0039.JPG'
# Resized 'S1_E02_R5_PICT0043.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_E02_R5_PICT0043.JPG'
# Resized 'S1_E02_R5_PICT0144.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_E02_R5_PICT0144.JPG'
# Resized 'S1_E05_R4_PICT1002.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_E05_R4_PICT1002.JPG'
# Resized 'S1_E02_R5_PICT0142.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_E02_R5_PICT0142.JPG'
# Resized 'S1_E05_R4_PICT0998.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_E05_R4_PICT0998.JPG'
# Resized 'S1_E05_R4_PICT0999.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_E05_R4_PICT0999.JPG'
# Resized 'S1_E02_R5_PICT0045.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_E02_R5_PICT0045.JPG'
# Resized 'S1_E05_R4_PICT1000.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_E05_R4_PICT1000.JPG'
# Resized 'S1_E05_R4_PICT0997.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_E05_R4_PICT0997.JPG'
# Resized 'S1_E02_R5_PICT0143.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_E02_R5_PICT0143.JPG'
# Resized 'S1_E05_R4_PICT0996.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_E05_R4_PICT0996.JPG'
# Resized 'S1_E05_R4_PICT1005.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_E05_R4_PICT1005.JPG'
# Resized 'S1_E05_R4_PICT1003.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_E05_R4_PICT1003.JPG'
# Resized 'S1_E05_R4_PICT1004.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_E05_R4_PICT1004.JPG'
# Resized 'S1_E05_R4_PICT1001.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_E05_R4_PICT1001.JPG'
# Resized 'S1_E05_R4_PICT0995.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_E05_R4_PICT0995.JPG'
# Resized 'S1_E05_R4_PICT1008.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_E05_R4_PICT1008.JPG'
# Resized 'S1_E05_R4_PICT1165.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_E05_R4_PICT1165.JPG'
# Resized 'S1_E05_R4_PICT1163.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_E05_R4_PICT1163.JPG'
# Resized 'S1_E05_R4_PICT1164.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_E05_R4_PICT1164.JPG'
# Resized 'S1_E05_R4_PICT1050.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_E05_R4_PICT1050.JPG'
# Resized 'S1_E05_R4_PICT1051.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_E05_R4_PICT1051.JPG'
# Resized 'S1_E05_R4_PICT1007.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_E05_R4_PICT1007.JPG'
# Resized 'S1_E05_R4_PICT1006.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_E05_R4_PICT1006.JPG'
# Resized 'S1_E05_R4_PICT1009.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_E05_R4_PICT1009.JPG'
# Resized 'S1_E05_R4_PICT1049.JPG' and saved to '/content/drive/MyDrive/serengeti eler/S1_E05_R4_PICT1049.JPG'

# %%
import os
import cv2
import numpy as np
from concurrent.futures import ProcessPoolExecutor  # Parallel processing

# Compute Euclidean distance using NumPy
def euclidean_distance(p1, p2):
    return np.sqrt(np.sum((p1 - p2) ** 2, axis=-1))

# Estimate local noise standard deviation and select optimal window size
def estimate_local_noise(image, y, x, max_window_size=7):
    min_window = 3  # Minimum window size
    max_window = max_window_size if max_window_size % 2 == 1 else max_window_size - 1  # Ensure it's odd
    noise_levels = []

    for window_size in range(min_window, max_window + 1, 2):
        offset = window_size // 2
        region = image[max(y-offset, 0):min(y+offset+1, image.shape[0]),
                       max(x-offset, 0):min(x+offset+1, image.shape[1])]
        noise_levels.append(np.std(region))  # Compute standard deviation

    noise_levels = np.array(noise_levels)  # Convert list to NumPy array
    optimal_idx = int(np.argmin(noise_levels))  # Ensure integer index
    optimal_window_size = min_window + optimal_idx * 2

    return noise_levels[optimal_idx], optimal_window_size

# Compute adaptive threshold `d_adaptive` with dynamic β
def compute_d_adaptive(image, y, x, d_base=30, max_window_size=7):
    sigma_local, window_size = estimate_local_noise(image, y, x, max_window_size)

    # Dynamic β function
    beta = 0.5 + 1.0 * (sigma_local / 15)  # β scales with noise, max at 1.5
    beta = min(max(beta, 0.5), 1.5)  # Clamp β between 0.5 and 1.5

    return d_base + beta * sigma_local, window_size  # Adaptive threshold

# Optimized FAPG Filtering with Dynamic Window Size
def optimized_fapg_filter(image, d_base=30, max_window_size=7):
    image = image.astype(np.float32)
    height, width, _ = image.shape
    filtered_image = image.copy()

    for y in range(height):
        for x in range(width):
            central_pixel = image[y, x]
            d_threshold, window_size = compute_d_adaptive(image, y, x, d_base, max_window_size)
            offset = window_size // 2

            # Collect neighbors dynamically
            y_range = slice(max(y-offset, 0), min(y+offset+1, height))
            x_range = slice(max(x-offset, 0), min(x+offset+1, width))
            neighbors = image[y_range, x_range]

            # Compute distances
            distances = euclidean_distance(central_pixel, neighbors.reshape(-1, 3))

            # Select pixels within the adaptive threshold
            mask = distances < d_threshold
            if np.sum(mask) == 0:
                continue

            peer_group = neighbors.reshape(-1, 3)[mask]
            weights = np.exp(-distances[mask] ** 2 / (4 * d_threshold ** 2))  # Vectorized weight computation
            weights /= np.sum(weights)  # Normalize weights

            # Weighted sum of peer group
            filtered_image[y, x] = np.sum(weights[:, np.newaxis] * peer_group, axis=0)

    return np.clip(filtered_image, 0, 255).astype(np.uint8)

# Process a single image (for parallel execution)
def process_single_image(file_name, input_folder, output_folder, d_base, max_window_size):
    input_path = os.path.join(input_folder, file_name)

    if not file_name.lower().endswith(('.jpg', '.png', '.jpeg')):
        print(f"Skipping non-image file: {file_name}")
        return

    image = cv2.imread(input_path)
    if image is None:
        print(f"Error: Unable to load image {file_name}. Skipping...")
        return

    rgb_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    # Apply Optimized FAPG filter
    filtered_image = optimized_fapg_filter(rgb_image, d_base=d_base, max_window_size=max_window_size)

    # Save filtered image
    output_path = os.path.join(output_folder, file_name)
    cv2.imwrite(output_path, cv2.cvtColor(filtered_image, cv2.COLOR_RGB2BGR))

    print(f"Processed and saved: {output_path}")

# Parallelized processing using multiple CPU cores
def process_images(input_folder, output_folder, d_base=30, max_window_size=7, num_workers=4):
    os.makedirs(output_folder, exist_ok=True)
    file_list = [f for f in os.listdir(input_folder) if f.lower().endswith(('.jpg', '.png', '.jpeg'))]

    with ProcessPoolExecutor(max_workers=num_workers) as executor:
        executor.map(process_single_image, file_list,
                     [input_folder] * len(file_list),
                     [output_folder] * len(file_list),
                     [d_base] * len(file_list),
                     [max_window_size] * len(file_list))

# **Set Paths Below**
input_folder = "/content/drive/MyDrive/serengeti eler"
output_folder = "/content/drive/MyDrive/serengeti elerf"

# Run the Optimized FAPG process with parallel execution
process_images(input_folder, output_folder, d_base=30, max_window_size=7, num_workers=4)
# Out:
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_B06_R1_PICT0007.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_B05_R3_PICT0039.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_B05_R3_PICT0038.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_B05_R1_PICT0056.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_B05_R1_PICT0057.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_B05_R3_PICT0056.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_B05_R3_PICT0058.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_B06_R1_PICT0038.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_B05_R3_PICT0040.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_B06_R1_PICT0008.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_B05_R3_PICT0057.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_B06_R1_PICT0037.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_B06_R2_PICT0028.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_B06_R1_PICT0039.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_B06_R2_PICT0006.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_B07_R1_PICT0435.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_B06_R1_PICT0049.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_B06_R1_PICT0065.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_B06_R1_PICT0064.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_B06_R1_PICT0056.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_B06_R2_PICT0029.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_B06_R1_PICT0048.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_B06_R1_PICT0067.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_B06_R1_PICT0066.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_C05_R3_PICT0170.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_C06_R1_PICT0056.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_B06_R2_PICT0027.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_C05_R3_PICT0171.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_C05_R3_PICT0172.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_C06_R3_PICT2297.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_B07_R1_PICT0437.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_C05_R3_PICT0899.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_C05_R3_PICT0901.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_C05_R3_PICT0898.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_C05_R3_PICT0897.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_B07_R1_PICT0436.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_C05_R3_PICT0900.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_C06_R4_PICT0182.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_C06_R4_PICT0454.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_C06_R4_PICT0185.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_C06_R4_PICT0183.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_C06_R4_PICT0465.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_C06_R4_PICT0452.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_C06_R3_PICT2298.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_C06_R4_PICT0184.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_C06_R4_PICT0453.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_C06_R4_PICT0464.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_C06_R4_PICT0186.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_C06_R3_PICT2299.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D03_R2_PICT0020.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_C06_R4_PICT0187.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D03_R1_PICT0016.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_C06_R4_PICT0493.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D02_R1_PICT1841.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D02_R1_PICT1842.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D02_R1_PICT1249.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D02_R1_PICT1248.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D02_R1_PICT1843.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_C06_R4_PICT0492.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_C06_R4_PICT0491.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D02_R1_PICT1247.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_C06_R4_PICT0466.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D02_R1_PICT1255.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D03_R1_PICT0046.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D03_R5_PICT0407.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D03_R2_PICT0022.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D03_R7_PICT0090.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D03_R2_PICT0021.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D03_R7_PICT0097.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D03_R7_PICT0095.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D03_R7_PICT0094.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D03_R7_PICT0096.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D03_R7_PICT0088.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D03_R7_PICT0092.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D03_R5_PICT0408.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D03_R7_PICT0089.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D03_R7_PICT0093.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D03_R5_PICT0406.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D03_R7_PICT0091.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D03_R7_PICT0101.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D03_R7_PICT0098.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D03_R7_PICT0099.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D03_R7_PICT0103.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D03_R7_PICT0105.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D04_R4_PICT0123.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D03_R7_PICT0107.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D03_R7_PICT0102.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D03_R7_PICT0104.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D03_R7_PICT0108.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D03_R7_PICT0100.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D03_R7_PICT0106.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D04_R1_PICT0118.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D04_R4_PICT0173.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D04_R5_PICT0042.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D04_R4_PICT0127.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D04_R5_PICT0043.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D04_R4_PICT0126.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D04_R4_PICT0171.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D04_R4_PICT0124.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D04_R4_PICT0128.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D04_R5_PICT0041.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D04_R4_PICT0172.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D04_R5_PICT0127.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D04_R5_PICT0126.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D04_R5_PICT0158.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D04_R5_PICT0155.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D04_R6_PICT0020.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D04_R5_PICT0160.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D04_R6_PICT0019.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D04_R6_PICT0018.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D04_R6_PICT0017.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D04_R5_PICT0157.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D04_R6_PICT0021.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D04_R5_PICT0156.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D04_R5_PICT0159.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D04_R5_PICT0125.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D04_R6_PICT0022.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D06_R1_PICT1875.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D06_R1_PICT2722.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D04_R6_PICT0462.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D04_R6_PICT0461.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D06_R2_PICT0423.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D07_R1_PICT0030.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D06_R2_PICT0422.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D06_R2_PICT0424.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D06_R1_PICT1874.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D07_R1_PICT0033.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D07_R1_PICT0003.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D07_R1_PICT0007.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D04_R6_PICT0463.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D07_R1_PICT0005.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D07_R2_PICT0023.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D07_R1_PICT0042.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D07_R1_PICT0041.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D07_R2_PICT0020.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D07_R2_PICT0025.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D07_R2_PICT0021.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D07_R2_PICT0027.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D07_R2_PICT0030.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D07_R2_PICT0028.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D07_R1_PICT0034.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D07_R2_PICT0024.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D07_R2_PICT0026.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D07_R2_PICT0022.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D07_R2_PICT0029.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D07_R3_PICT0085.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D07_R3_PICT0084.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D07_R3_PICT0071.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D07_R3_PICT0072.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D07_R3_PICT0252.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D07_R3_PICT0251.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D07_R2_PICT0036.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D07_R3_PICT0086.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D07_R2_PICT0037.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D07_R2_PICT0031.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D07_R3_PICT0088.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D07_R3_PICT0073.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D07_R2_PICT0035.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D07_R3_PICT0083.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D07_R3_PICT0087.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D11_R1_PICT0027.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D07_R3_PICT0266.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D07_R3_PICT0260.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D07_R3_PICT0256.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D07_R3_PICT0257.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D07_R3_PICT0254.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D07_R3_PICT0262.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D07_R3_PICT0268.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D07_R3_PICT0255.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D11_R1_PICT0026.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D07_R3_PICT0253.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D07_R3_PICT0267.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D07_R3_PICT0259.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D07_R3_PICT0258.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D07_R3_PICT0261.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D11_R1_PICT0045.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D12_R1_PICT0309.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D11_R1_PICT0046.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_E02_R3_PICT0120.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D11_R1_PICT0028.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D11_R1_PICT0044.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_E02_R3_PICT0119.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D12_R1_PICT0308.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D12_R1_PICT0305.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D12_R1_PICT0306.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D12_R1_PICT0307.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_D12_R1_PICT0310.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_E02_R5_PICT0029.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_E02_R5_PICT0030.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_E02_R3_PICT0147.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_E02_R5_PICT0021.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_E02_R3_PICT0122.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_E02_R3_PICT0148.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_E02_R3_PICT0124.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_E02_R3_PICT0151.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_E02_R5_PICT0028.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_E02_R3_PICT0149.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_E02_R3_PICT0121.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_E02_R3_PICT0150.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_E02_R3_PICT0123.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_E02_R3_PICT0146.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_E02_R5_PICT0032.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_E02_R5_PICT0035.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_E02_R5_PICT0042.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_E02_R5_PICT0044.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_E02_R5_PICT0034.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_E02_R5_PICT0040.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_E02_R5_PICT0041.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_E02_R5_PICT0038.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_E02_R5_PICT0033.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_E02_R5_PICT0031.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_E02_R5_PICT0037.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_E02_R5_PICT0036.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_E02_R5_PICT0039.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_E02_R5_PICT0043.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_E02_R5_PICT0144.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_E05_R4_PICT1002.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_E02_R5_PICT0142.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_E05_R4_PICT0998.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_E05_R4_PICT0999.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_E02_R5_PICT0045.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_E05_R4_PICT1000.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_E05_R4_PICT0997.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_E02_R5_PICT0143.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_E05_R4_PICT0996.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_E05_R4_PICT1005.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_E05_R4_PICT1003.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_E05_R4_PICT1004.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_E05_R4_PICT1001.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_E05_R4_PICT1008.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_E05_R4_PICT0995.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_E05_R4_PICT1165.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_E05_R4_PICT1163.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_E05_R4_PICT1050.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_E05_R4_PICT1164.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_E05_R4_PICT1051.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_E05_R4_PICT1007.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_E05_R4_PICT1009.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_E05_R4_PICT1006.JPG
# Processed and saved: /content/drive/MyDrive/serengeti elerf/S1_E05_R4_PICT1049.JPG
